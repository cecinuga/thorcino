# %% [markdown]
# ## MLP vs. LSTM
#
# The aim of this notebook is to show how a LSTM is not even the propery model for a time series problem, for this case we will show how a simple MLP can outperform a LSTM in a time series forecasting task.
#
# And then there will explained when an LSTM is the right model to use for time series forecasting.

# %% [markdown]
# ### The Training Problem
